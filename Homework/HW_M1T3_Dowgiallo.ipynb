# %%
import  pandas  as pd
import  numpy  as np
import  matplotlib.pyplot  as plt

# %%
census = pd.read_csv('census.csv')
                
census
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 0           2000         Florida              14550.0   44    Male
# 1           2000         Florida              22800.0   20  Female
# 2           2000         Florida                  0.0   20    Male
# 3           2000         Florida              23000.0    6  Female
# 4           2000         Florida              48000.0   55    Male
# 5           2000         Florida              74000.0   43  Female
# 6           2000         Florida              23000.0   60  Female
# 7           2000         Florida              74000.0   47  Female
# 8           2000         Florida              60000.0   54  Female
# 9           2000         Florida              14600.0   58  Female
# 10          2000         Florida                  0.0   33  Female
# 11          2000         Florida              37000.0   51  Female
# 12          2000         Florida              32000.0   62  Female
# ...

# %% [markdown]
# # Question 1
# The parameter ignore_index (if true) will give you the index of the original dataset, compared to where if it were false the index will be renumbered to the new dataset. Sort will allow you to sort the data in a specific way in an ascending or descending.

# %% [markdown]
# # Question 2

# %% [markdown]
# *COMMENT: That is how you tell the computer which columns to use, but if you're handed a dataframe, how you can see which columns are there?  1/2 pts*

# %% [markdown]
# The columns of this dataframe frame are census_year, state_fips_code, total_family_income, age, sex, race_general, marital_status, and total_personal_income.

# %% [markdown]
#  usecols = [ 'census_year' , 'state_fips_code' , 'total_family_income' , 'age' , 'sex' , 'race_general' , 'marital_status' , 'total_personal_income' ]

# %% [markdown]
# # Question 3

# %%
census[19:45]
# Out:
#     census_year state_fips_code  total_family_income  age     sex  \
# 19         2000         Florida              43950.0   69  Female
# 20         2000         Florida              49000.0   31    Male
# 21         2000         Florida              31600.0   80  Female
# 22         2000         Florida              50090.0    2    Male
# 23         2000         Florida              64800.0   47    Male
# 24         2000         Florida              90000.0   12    Male
# 25         2000         Florida              38320.0   47    Male
# 26         2000         Florida             103700.0    8  Female
# 27         2000         Florida                  0.0   67    Male
# 28         2000         Florida              70700.0   17  Female
# 29         2000         Florida              64800.0   69  Female
# 30         2000         Florida              60000.0   55    Male
# 31         2000         Florida             118100.0   18  Female
# ...

# %%
census[23:26][['age', 'sex' , 'race_general']]
# Out:
#     age   sex race_general
# 23   47  Male        White
# 24   12  Male        White
# 25   47  Male        White

# %%
census[45:46]
# Out:
#     census_year state_fips_code  total_family_income  age     sex  \
# 45         2000        New York              68020.0    2  Female
#
#    race_general        marital_status  total_personal_income
# 45      Chinese  Never married/single                    NaN

# %%
census[['census_year' , 'state_fips_code']]
# Out:
#      census_year state_fips_code
# 0           2000         Florida
# 1           2000         Florida
# 2           2000         Florida
# 3           2000         Florida
# 4           2000         Florida
# 5           2000         Florida
# 6           2000         Florida
# 7           2000         Florida
# 8           2000         Florida
# 9           2000         Florida
# 10          2000         Florida
# 11          2000         Florida
# 12          2000         Florida
# 13          2000         Florida
# 14          2000         Florida
# 15          2000         Florida
# 16          2000         Florida
# 17          2000         Florida
# 18          2000         Florida
# 19          2000         Florida
# 20          2000         Florida
# 21          2000         Florida
# 22          2000         Florida
# 23          2000         Florida
# 24          2000         Florida
# 25          2000         Florida
# 26          2000         Florida
# ...

# %% [markdown]
# # Question 4

# %% [markdown]
# *COMMENT: just rename the age column and print that out, e.g.*
#
# age = census['age']
# print age
#
# 1/2 pts

# %%
census_extra = census
census_extra['age_doubled'] = census_extra['age']*2
census_extra['age_doubled']
# Out:
# 0       88
# 1       40
# 2       40
# 3       12
# 4      110
# 5       86
# 6      120
# 7       94
# 8      108
# 9      116
# 10      66
# 11     102
# 12     124
# 13      16
# 14      50
# 15      88
# 16      56
# 17       2
# 18      62
# 19     138
# 20      62
# 21     160
# 22       4
# 23      94
# 24      24
# 25      94
# 26      16
# 27     134
# 28      34
# 29     138
#       ...
# 470      2
# 471     58
# 472    122
# 473     72
# 474     50
# 475     82
# 476     18
# 477     20
# 478     26
# 479      6
# 480     30
# 481     64
# 482    136
# 483     64
# 484     64
# 485     48
# 486     36
# 487     82
# 488     12
# 489     76
# 490     86
# 491    152
# 492     48
# 493     72
# 494     10
# 495    136
# 496     24
# 497    120
# 498    120
# 499     94
# Name: age_doubled, Length: 500, dtype: int64

# %% [markdown]
# # Question 5

# %%
fake_census = census
fake_census.drop('census_year',inplace=True, axis=1)
fake_census

new_rows_dict = {
    'state_fips_code' : ['Rhode Island', 'Connecticut'],
    'total_family_income' :[2000.0, 45.0],
    'age' : [98, 2],
    'sex' : ['Male', 'Female'],
    'race_general' : ['White', 'Black'],
    'marital_status' : ['Single', 'Married'],
    'total_personal_income' : [2000.0, 2.0]   
}

new_rows_df = pd.DataFrame(new_rows_dict)
new_rows_df
fake_census_new_rows = fake_census.append(new_rows_df, ignore_index=True, sort=False)

fake_census_new_rows
# Out:
#     state_fips_code  total_family_income  age     sex     race_general  \
# 0           Florida              14550.0   44    Male  Two major races
# 1           Florida              22800.0   20  Female            White
# 2           Florida                  0.0   20    Male            Black
# 3           Florida              23000.0    6  Female            White
# 4           Florida              48000.0   55    Male            White
# 5           Florida              74000.0   43  Female            White
# 6           Florida              23000.0   60  Female            White
# 7           Florida              74000.0   47  Female            White
# 8           Florida              60000.0   54  Female            Black
# 9           Florida              14600.0   58  Female            White
# 10          Florida                  0.0   33  Female            White
# 11          Florida              37000.0   51  Female            White
# ...

# %% [markdown]
# # Question 6

# %%
census[census['state_fips_code'] == 'Connecticut']
# Out:
#     state_fips_code  total_family_income  age     sex race_general  \
# 274     Connecticut                  NaN   56  Female        Black
# 275     Connecticut                  0.0   52    Male        White
# 276     Connecticut              80100.0   16    Male        White
# 277     Connecticut             129300.0   32  Female        White
#
#              marital_status  total_personal_income
# 274    Never married/single                 3600.0
# 275                Divorced                51000.0
# 276    Never married/single                    0.0
# 277  Married/spouse present                34300.0

# %%
census[census['total_family_income'] < 75000]  [['total_family_income']]
# Out:
#      total_family_income
# 0                14550.0
# 1                22800.0
# 2                    0.0
# 3                23000.0
# 4                48000.0
# 5                74000.0
# 6                23000.0
# 7                74000.0
# 8                60000.0
# 9                14600.0
# 10                   0.0
# 11               37000.0
# 12               32000.0
# 16               48000.0
# 17               48000.0
# 18               57200.0
# 19               43950.0
# 20               49000.0
# 21               31600.0
# 22               50090.0
# 23               64800.0
# 25               38320.0
# 27                   0.0
# 28               70700.0
# 29               64800.0
# 30               60000.0
# 32               21000.0
# 33               40000.0
# 34               17300.0
# 35               61300.0
# ..                   ...
# 461               9400.0
# 462              74000.0
# 463              25280.0
# 464              55500.0
# 465              22200.0
# ...

# %%
census[ (census['age'] > 30) & (census['age'] < 50)] [['age']]
# Out:
#      age
# 0     44
# 5     43
# 7     47
# 10    33
# 15    44
# 18    31
# 20    31
# 23    47
# 25    47
# 40    46
# 43    35
# 47    36
# 55    33
# 57    40
# 58    34
# 60    49
# 62    37
# 64    40
# 70    36
# 72    32
# 75    47
# 78    46
# 83    39
# 86    40
# 88    43
# 90    40
# 93    46
# 98    48
# 110   45
# 121   46
# ..   ...
# 398   49
# 402   39
# 409   31
# 416   40
# 420   49
# 425   35
# 427   33
# 431   37
# 436   40
# 440   37
# 442   49
# 443   44
# 444   31
# 452   32
# 453   46
# 454   45
# 456   31
# 458   41
# 460   44
# 468   42
# 473   36
# 475   41
# 481   32
# 483   32
# 484   32
# 487   41
# 489   38
# 490   43
# 493   36
# 499   47
#
# [153 rows x 1 columns]

# %%
census[ (census['race_general'] == 'White') | (census['race_general'] == 'Black')] [['race_general']]
# Out:
#     race_general
# 1          White
# 2          Black
# 3          White
# 4          White
# 5          White
# 6          White
# 7          White
# 8          Black
# 9          White
# 10         White
# 11         White
# 12         White
# 13         White
# 14         White
# 15         White
# 16         White
# 17         White
# 18         White
# 19         White
# 20         White
# 21         White
# 22         White
# 23         White
# 24         White
# 25         White
# 26         White
# 27         Black
# 28         White
# 29         White
# 30         White
# ..           ...
# 469        White
# 470        White
# 471        White
# 472        White
# 473        Black
# 474        White
# 475        White
# 476        White
# 477        Black
# 478        White
# 479        White
# 481        Black
# 482        White
# 483        White
# 484        White
# 485        White
# 486        White
# 487        White
# 488        White
# 489        White
# ...

# %% [markdown]
# # Question 7

# %%
census[census['total_personal_income'].isnull()]
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 3           2000         Florida              23000.0    6  Female
# 13          2000         Florida             113000.0    8    Male
# 17          2000         Florida              48000.0    1    Male
# 22          2000         Florida              50090.0    2    Male
# 24          2000         Florida              90000.0   12    Male
# 26          2000         Florida             103700.0    8  Female
# 37          2000         Florida               6000.0    2    Male
# 44          2000        New York              13000.0    1    Male
# 45          2000        New York              68020.0    2  Female
# 49          2000        New York              12400.0    7    Male
# 51          2000        New York              65000.0    1  Female
# 54          2000        New York              81710.0   14    Male
# 59          2000        New York             168200.0    6  Female
# ...

# %% [markdown]
# # Question 8

# %%
census.isnull()
# Out:
#      state_fips_code  total_family_income    age    sex  race_general  \
# 0              False                False  False  False         False
# 1              False                False  False  False         False
# 2              False                False  False  False         False
# 3              False                False  False  False         False
# 4              False                False  False  False         False
# 5              False                False  False  False         False
# 6              False                False  False  False         False
# 7              False                False  False  False         False
# 8              False                False  False  False         False
# 9              False                False  False  False         False
# 10             False                False  False  False         False
# 11             False                False  False  False         False
# ...

# %% [markdown]
# I see that every value listed is either true or false.
