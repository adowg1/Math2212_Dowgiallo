# %%
import  pandas  as pd
import  numpy  as np
import  matplotlib.pyplot  as plt

# %%
census = pd.read_csv('census.csv')
               
census.head()
# Out:
#    census_year state_fips_code  total_family_income  age     sex  \
# 0         2000         Florida              14550.0   44    Male
# 1         2000         Florida              22800.0   20  Female
# 2         2000         Florida                  0.0   20    Male
# 3         2000         Florida              23000.0    6  Female
# 4         2000         Florida              48000.0   55    Male
#
#       race_general          marital_status  total_personal_income
# 0  Two major races  Married/spouse present                    0.0
# 1            White    Never married/single                13000.0
# 2            Black    Never married/single                20000.0
# 3            White    Never married/single                    NaN
# 4            White  Married/spouse present                36000.0

# %% [markdown]
# # Question 1

# %% [markdown]
# It executes a statement or multiple statements. If the first is not true then it continues to the next and if false and then final will be the answer.

# %% [markdown]
# *(instructor comment) actually define one, this is a good description of what it is though. 2/4*

# %% [markdown]
# # Question 2

# %% [markdown]
# The rank function assigns a rank to tie scores by following a strategy function. The strategy has multiple parameters such as length and then length + 1.

# %% [markdown]
# *instructor comment: what are some examples of strategy functions? 3/4*

# %% [markdown]
# # Question 3

# %% [markdown]
# *instructor comment: don't forget to remove missing data with dropna*

# %%
census2 = census
census2['total_family_income_squarerooted'] = census2['total_family_income'].apply(np.sqrt)
census2
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 0           2000         Florida              14550.0   44    Male
# 1           2000         Florida              22800.0   20  Female
# 2           2000         Florida                  0.0   20    Male
# 3           2000         Florida              23000.0    6  Female
# 4           2000         Florida              48000.0   55    Male
# 5           2000         Florida              74000.0   43  Female
# 6           2000         Florida              23000.0   60  Female
# 7           2000         Florida              74000.0   47  Female
# 8           2000         Florida              60000.0   54  Female
# 9           2000         Florida              14600.0   58  Female
# 10          2000         Florida                  0.0   33  Female
# 11          2000         Florida              37000.0   51  Female
# 12          2000         Florida              32000.0   62  Female
# ...

# %%
census3 = census
census3['2020_dollars_adjusted'] = census3['total_family_income'].apply(lambda f: f*1.0102**20)
census3
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 0           2000         Florida              14550.0   44    Male
# 1           2000         Florida              22800.0   20  Female
# 2           2000         Florida                  0.0   20    Male
# 3           2000         Florida              23000.0    6  Female
# 4           2000         Florida              48000.0   55    Male
# 5           2000         Florida              74000.0   43  Female
# 6           2000         Florida              23000.0   60  Female
# 7           2000         Florida              74000.0   47  Female
# 8           2000         Florida              60000.0   54  Female
# 9           2000         Florida              14600.0   58  Female
# 10          2000         Florida                  0.0   33  Female
# 11          2000         Florida              37000.0   51  Female
# 12          2000         Florida              32000.0   62  Female
# ...

# %%
census4 = census
census4['Birth_year'] = census4['census_year'] - census4['age']
census4
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 0           2000         Florida              14550.0   44    Male
# 1           2000         Florida              22800.0   20  Female
# 2           2000         Florida                  0.0   20    Male
# 3           2000         Florida              23000.0    6  Female
# 4           2000         Florida              48000.0   55    Male
# 5           2000         Florida              74000.0   43  Female
# 6           2000         Florida              23000.0   60  Female
# 7           2000         Florida              74000.0   47  Female
# 8           2000         Florida              60000.0   54  Female
# 9           2000         Florida              14600.0   58  Female
# 10          2000         Florida                  0.0   33  Female
# 11          2000         Florida              37000.0   51  Female
# 12          2000         Florida              32000.0   62  Female
# ...

# %% [markdown]
# # Question 4

# %%
census_males = census.sort_values(by = 'total_family_income', ascending = True, inplace = False)
census_males[(census_males['sex'] == 'Male')].head()
# Out:
#      census_year state_fips_code  total_family_income  age   sex  \
# 36          2000         Florida                  0.0   18  Male
# 47          2000        New York                  0.0   36  Male
# 402         2000      Washington                  0.0   39  Male
# 408         2000   West Virginia                  0.0   87  Male
# 27          2000         Florida                  0.0   67  Male
#
#                          race_general        marital_status  \
# 36                              White  Never married/single
# 47                              White  Never married/single
# 402  American Indian or Alaska Native  Never married/single
# 408                             White               Widowed
# 27                              Black               Widowed
#
#      total_personal_income  total_family_income_squarerooted  \
# 36                  2000.0                               0.0
# 47                 17500.0                               0.0
# ...

# %%
census_females = census.sort_values(by = 'total_family_income', ascending = False, inplace = False)
census_females[(census_females['sex'] == 'Female')].head()
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 151         2000      California             378200.0   52  Female
# 239         2000           Texas             348000.0   36  Female
# 333         2000         Georgia             206700.0   10  Female
# 59          2000        New York             168200.0    6  Female
# 91          2000      California             156000.0   65  Female
#
#     race_general          marital_status  total_personal_income  \
# 151        White  Married/spouse present                    0.0
# 239        White  Married/spouse present                15000.0
# 333        White    Never married/single                    NaN
# 59         White    Never married/single                    NaN
# 91         White  Married/spouse present                10000.0
#
#      total_family_income_squarerooted  2020_dollars_adjusted  Birth_year
# 151                        614.979674          463306.942527        1948
# ...

# %% [markdown]
# # Question 5

# %%
average_family_income = census[['state_fips_code', 'total_family_income']].groupby('state_fips_code').mean()

average_family_income
# Out:
#                       total_family_income
# state_fips_code
# Alabama                      29724.000000
# Arizona                      30185.714286
# Arkansas                     10940.000000
# California                   73141.639344
# Colorado                    245187.500000
# Connecticut                  69800.000000
# Delaware                     51600.000000
# District of Columbia         77840.000000
# Florida                      46848.205128
# Georgia                      60488.470588
# Hawaii                       76447.000000
# Idaho                        38800.000000
# Illinois                     55971.500000
# Indiana                      46738.125000
# Iowa                         40904.000000
# Kansas                       29266.666667
# Kentucky                    112150.000000
# Louisiana                    34899.090909
# Maine                        10700.000000
# Maryland                    102395.555556
# Massachusetts                59505.833333
# ...

# %% [markdown]
# # Question 6

# %%
average_age = census[['race_general', 'age']].groupby('race_general').mean()

average_age
# Out:
#                                         age
# race_general
# American Indian or Alaska Native  33.333333
# Black                             35.704225
# Chinese                           34.125000
# Japanese                          48.000000
# Other                             26.680000
# Other Asian or Pacific Islander   31.846154
# Two major races                   26.062500
# White                             36.349862

# %% [markdown]
# # Question 7

# %%
# Print a pivot table that gives the average personal income in each state, separating by sex. 

ptable_personal_income = pd.pivot_table( 
    census,
    values = 'total_personal_income',
    index = 'state_fips_code',
    columns = 'sex',
    aggfunc = np.mean
)
ptable_personal_income
# Out:
# sex                         Female           Male
# state_fips_code
# Alabama                9833.333333   47950.000000
# Arizona               20000.000000   29500.000000
# California            14334.482759   62713.809524
# Colorado              26700.000000  153033.333333
# Connecticut           18950.000000   25500.000000
# Delaware               9100.000000            NaN
# District of Columbia  30000.000000   17190.000000
# Florida               18494.444444   22933.571429
# Georgia               24405.714286   34317.714286
# Hawaii                28300.000000            NaN
# Idaho                          NaN   23000.000000
# Illinois              16966.666667   33791.111111
# Indiana               19390.000000   18084.000000
# Iowa                  14300.000000   28500.000000
# Kansas                  484.000000   41000.000000
# Kentucky              13600.000000  145950.000000
# Louisiana             16050.000000   23462.500000
# ...

# %% [markdown]
# # Question 8

# %%
census.plot(x= 'age', y = 'total_personal_income', kind = 'scatter', title = 'Personal Income by Age')

# %% [markdown]
# # Question 9

# %%
census['total_family_income'].hist()

# %% [markdown]
# # Question 10

# %%
average_family_income['total_family_income'].hist()
